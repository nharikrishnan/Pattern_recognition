# %%
# import statements
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import utils
from utils import *
import bayes_optimal_classifier
import feature_trans
import data_generation

# %%
feature_trans = feature_trans.feature_operations()
data_gen = data_generation.data_generation()
bayes_optimal  = bayes_optimal_classifier.bayesOptimal()

# %%
def accuracy(matrix_predicted,c):
    count_class1 = 0
    for i in range(len(matrix_predicted.tolist())):
        if int(matrix_predicted.tolist()[i][3]) == c:
            count_class1 = count_class1 +1
    return (count_class1/200)*100
# for i in range(len(matrix_predicted2.tolist())):
#     if int(matrix_predicted2.tolist()[i][3]) == 1:
#         count_class2 = count_class2 +1

# %%
covariance_matrix1, covariance_matrix2 = utils.generate_covariance_mat(a=3, b=4, c=6, alpha=.2, beta=0.1)
mean_vector1 = np.array([2,4,6])
mean_vector2 = np.array([2,-4,-6])
#generating 200 point for class1 and class2
data_gen = data_generation.data_generation()
random_gaussian_matrix1 = data_gen.gausian_random(200,3)
random_gaussian_matrix2 = data_gen.gausian_random(200,3)
matrix_train1= data_gen.generate_cov_data( random_gaussian_matrix1.T,covariance_matrix1, mean_vector1)
matrix_train2= data_gen.generate_cov_data( random_gaussian_matrix2.T,covariance_matrix2,mean_vector2)
# creating dataframe with 2 classes
df_train = create_df(matrix_train1, matrix_train2)

# %%
#calculating the coefficients A,B,C for quadratic bayes optimal classifier
A, B, C = bayes_optimal.fit_model(matrix_train1, matrix_train2)

# %%
def calc_prediction_score(x,y, A,B,C):
    return (A[0][0]*(x**2) +
           A[1][1]*(y**2) + 
           (A[0][1] +A[1][0])*x*y + 
           (2*A[0][2] + 2*A[2][0] + B[0])*x + 
           (2*A[1][2] + 2*A[2][1] +B[1])*y + 
           2*B[2] +A[2][2]*(4) +C)

# %%
import seaborn as sns
import itertools
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.colors as colors
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits import mplot3d
from sklearn import linear_model, datasets
import seaborn as sns
import itertools

# %%
N = 200
x = np.linspace(-15, 15, N)
y= np.linspace(-15, 15, N)
X, Y = np.meshgrid(x, y)
zz = np.array([calc_prediction_score(xx,yy, A, B, C) for xx, yy in  zip(np.ravel(X), np.ravel(Y)) ])

# %%
zz_new =[]
for i in range(len(X)):
    zz_new.append(calc_prediction_score(X[i],Y[i], A, B, C))

# %%
len(zz_new)
# Out:
# 200

# %%
Z = zz.reshape(X.shape)

# %%
df_new = create_df(matrix_train1, matrix_train2)

# %%
df_new.columns
# Out:
# Index(['X1', 'X2', 'X3', 'Class'], dtype='object')

# %%
# %matplotlib notebook

# %%
g = sns.FacetGrid(df_new, hue="Class", size=10, palette = 'colorblind') .map(plt.scatter, "X1", "X2",)  .add_legend()
my_ax = g.ax

my_ax.contourf( X, Y, Z, 2, alpha = .1, colors = ('blue','red'))
# Out:
# C:\Users\hkpat\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# <img src="data:image/png;base64,..." width="1322.4">

# %%
zz.shape
# Out:
# (40000,)

# %%
zz
# Out:
# array([-10.21011431, -10.01399627,  -9.81998669, ...,   1.79205819,
#          1.61267772,   1.4311888 ])

# %%
len(X)
# Out:
# 200

# %%
zz = np.array([calc_prediction_score(xx[i],yy[i], A, B, C) for i in range(len(X)) ])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-ddfd016e6a4f> in <module>
# ----> 1 zz = np.array([calc_prediction_score(xx[i],yy[i], A, B, C) for i in range(len(X)) ])
#
# <ipython-input-52-ddfd016e6a4f> in <listcomp>(.0)
# ----> 1 zz = np.array([calc_prediction_score(xx[i],yy[i], A, B, C) for i in range(len(X)) ])
#
# NameError: name 'xx' is not defined

# %%
zz.shape
# Out:
# (40000,)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(matrix_train1.T[1], matrix_train1.T[2], c='r', marker='o', s=10, label = 'Class1')
ax.scatter(matrix_train2.T[1], matrix_train2.T[2], c='b', marker='o', s=10, label = 'Class2')
surf = ax.plot(yy, zz_new)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-b2b032de94b7> in <module>
#       3 ax.scatter(matrix_train1.T[1], matrix_train1.T[2], c='r', marker='o', s=10, label = 'Class1')
#       4 ax.scatter(matrix_train2.T[1], matrix_train2.T[2], c='b', marker='o', s=10, label = 'Class2')
# ----> 5 surf = ax.plot(yy, zz_new)
#
# NameError: name 'yy' is not defined

# %%
X
# Out:
# array([[-15.        , -14.84924623, -14.69849246, ...,  14.69849246,
#          14.84924623,  15.        ],
#        [-15.        , -14.84924623, -14.69849246, ...,  14.69849246,
#          14.84924623,  15.        ],
#        [-15.        , -14.84924623, -14.69849246, ...,  14.69849246,
#          14.84924623,  15.        ],
#        ...,
#        [-15.        , -14.84924623, -14.69849246, ...,  14.69849246,
#          14.84924623,  15.        ],
#        [-15.        , -14.84924623, -14.69849246, ...,  14.69849246,
#          14.84924623,  15.        ],
#        [-15.        , -14.84924623, -14.69849246, ...,  14.69849246,
#          14.84924623,  15.        ]])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(matrix_train1.T[0], matrix_train1.T[1], matrix_train1.T[2],c='r', marker='o', s=10, label = 'Class1')
ax.scatter(matrix_train2.T[0], matrix_train2.T[1], matrix_train2.T[2],c='b', marker='o', s=10, label = 'Class2')
surf = ax.plot(xx,yy, zz)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-7c9b6e5a5bdb> in <module>
#       3 ax.scatter(matrix_train1.T[0], matrix_train1.T[1], matrix_train1.T[2],c='r', marker='o', s=10, label = 'Class1')
#       4 ax.scatter(matrix_train2.T[0], matrix_train2.T[1], matrix_train2.T[2],c='b', marker='o', s=10, label = 'Class2')
# ----> 5 surf = ax.plot(xx,yy, zz)
#
# NameError: name 'xx' is not defined

# %%
matrix_train1
# Out:
# array([[ 1.91447651e+00,  2.50031222e+00,  1.76268847e+01],
#        [-2.03949926e+00, -2.27431855e+00,  8.81239424e+00],
#        [ 8.50675406e-01,  6.38416761e+00, -2.49219456e+00],
#        [ 2.77185064e+00, -4.57356432e+00,  4.86372139e+00],
#        [-1.76261293e+00,  9.37724923e+00,  4.96452428e+00],
#        [ 6.14200007e-01,  9.41692248e+00,  6.45368658e+00],
#        [ 1.84809612e+00, -6.51186064e-01,  1.23042012e+01],
#        [ 1.51242660e+00,  2.92933700e+00,  1.45428913e+01],
#        [ 4.94633528e+00,  1.05848444e+00, -1.56680257e+00],
#        [ 6.04715092e+00,  1.97598387e+00,  3.71110335e+00],
#        [ 7.37961126e+00,  1.05461177e+01,  1.19281360e+01],
#        [-1.12762424e+00, -5.54336470e+00,  9.79699842e-01],
#        [ 3.63211864e+00,  4.37402083e+00,  6.30361876e+00],
#        [ 5.17571228e+00, -1.45014825e+00,  1.05748751e+01],
#        [-1.60536566e-01,  4.09594877e+00,  7.27201561e+00],
#        [ 3.80647711e-01,  1.97489109e-01,  2.40600088e+00],
# ...

# %%
import sympy
from sympy import solve
# (A[0][0]*(x**2) +
#            A[1][1]*(y**2) + 
#            (A[0][1] +A[1][0])*x*y + 
#            (2*A[0][2] + 2*A[2][0] + B[0])*x + 
#            (2*A[1][2] + 2*A[2][1] +B[1])*y + 
#            2*B[2] +A[2][2]*(4) +C)

# %%
x = sympy.Symbol('x')
y = sympy.Symbol('y')

solution_x = solve((A[0][0]*(x**2) +
           A[1][1]*(y**2) + 
           (A[0][1] +A[1][0])*x*y + 
           (0*A[0][2] + 0*A[2][0] + B[0])*x + 
           (0*A[1][2] + 0*A[2][1] +B[1])*y + 
           0*B[2] +A[2][2]*(0) +C), y,x)

# %%
solution = solve(solution_x[1][0])

# %%
solution_x
# Out:
# [(-1.19763148448512*x - 1.35867320477793e-15*sqrt(7.60527147926251e+30*x**2 + 5.99815185018464e+31*x + 1.13576781332947e+33) - 49.9874163115576,
#   x),
#  (-1.19763148448512*x + 1.35867320477793e-15*sqrt(7.60527147926251e+30*x**2 + 5.99815185018464e+31*x + 1.13576781332947e+33) - 49.9874163115576,
#   x)]

# %%
solution
# Out:
# [-7.84604006039925, 8.89202022350810]

# %%
import math
from math import sqrt

# %%
def func_values(y):
    return solution_x[1][0]

# %%
x_vals = np.linspace(-15, 20, 200)
#x_vals = [0.0849493170289372*y + 9.50844878898309e-17*sqrt(1.07355177392785e+31*y**2 + 6.53991901705492e+32*y + 6.26787245847353e+33) + 0.766047504969191 for y in Y]

# %%
y1 = [-1.19763148448512*x + 1.35867320477793e-15*sqrt(7.60527147926251e+30*x**2 + 5.99815185018464e+31*x + 1.13576781332947e+33) - 49.9874163115576  for x in x_vals]

# %%
# x_vals

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(matrix_train1.T[1], matrix_train1.T[2], c='r', marker='o', s=10, label = 'Class1')
ax.scatter(matrix_train2.T[1], matrix_train2.T[2], c='b', marker='o', s=10, label = 'Class2')
surf = ax.plot(x_vals,y1)
# Out:
# <img src="data:image/png;base64,..." width="640">
